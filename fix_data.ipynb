# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
news_col = ['news_id', 'category', 'subcategory', 'title', 'abstract', 'url', 'title_entity', 'abstract_entity']
behaviors_col = ['impression_id', 'user', 'time', 'clicked_news', 'impressions']

news_df = pd.read_csv('./train/train_news.tsv', sep='\t', names=news_col, index_col='news_id')
behav_df = pd.read_csv('./train/train_behaviors.tsv', sep='\t', names=behaviors_col, index_col='impression_id')
entity_vec = pd.read_csv('./train/train_entity_embedding.vec', sep='\t', 
                         names=['WikidataId'] + list(range(100)), 
                         usecols=list(range(101)),
                         index_col='WikidataId')

# %%
# check columns with missing values
print('==== Columns w/ Missing Values ====')
print('[News Data]')
for col in news_df.columns:
    if news_df[col].isna().any():
        print(col)
        
print('\n[Behaviors Data]')
for col in behav_df.columns:
    if behav_df[col].isna().any():
        print(col)
# Out:
# ==== Columns w/ Missing Values ====
# [News Data]
# abstract
# title_entity
# abstract_entity
#
# [Behaviors Data]

# %%
# 資料沒有異常，單純缺值
news_df[news_df['abstract'].isna()]
# Out:
#           category        subcategory  \
# news_id
# N603780     health            medical
# N40392      health             cardio
# N67055     finance  finance-insurance
# N493460     sports      football_ncaa
# N96749   lifestyle      lifestylebuzz
# ...            ...                ...
# N819583     sports       football_nfl
# N139372       news             newsus
# N430180  lifestyle    lifestylefamily
# N522314      autos        autossports
# N397875     sports        more_sports
#
#                                                      title abstract  \
# news_id
# N603780  Dispose of unwanted prescription drugs during ...      NaN
# N40392   Check Houston traffic map for current road con...      NaN
# N67055   The States Where Dogs Put the Biggest Bite on ...      NaN
# N493460  Rutgers throws for 1 yard in 35-0 loss at Indiana      NaN
# N96749   Mom with schizophrenia, 6-year-old daughter mi...      NaN
# ...                                                    ...      ...
# N819583  Week 10 Game Balls: Few Bright Spots in Colts ...      NaN
# N139372  Winter homeless shelter remains unopened after...      NaN
# N430180  Family says 13-year-old Broadway star died fro...      NaN
# N522314                  Best Sports Car Deals for October      NaN
# N397875       Shall we dance: Sports stars shake their leg      NaN
#
#                                                    url  \
# news_id
# N603780  https://assets.msn.com/labs/mind/AAISxPN.html
# N40392   https://assets.msn.com/labs/mind/AAEKnO1.html
# N67055   https://assets.msn.com/labs/mind/AABrOCk.html
# N493460  https://assets.msn.com/labs/mind/AAIGv2m.html
# N96749   https://assets.msn.com/labs/mind/AAJfTsZ.html
# ...                                                ...
# N819583  https://assets.msn.com/labs/mind/BBWz39w.html
# N139372  https://assets.msn.com/labs/mind/BBWzAPK.html
# N430180  https://assets.msn.com/labs/mind/BBWzQYV.html
# N522314  https://assets.msn.com/labs/mind/BBy5rVe.html
# N397875  https://assets.msn.com/labs/mind/BBzMpnG.html
#
#                                               title_entity abstract_entity
# news_id
# N603780  [{"Label": "Drug Enforcement Administration", ...              []
# N40392   [{"Label": "Houston", "Type": "G", "WikidataId...              []
# N67055                                                  []              []
# N493460  [{"Label": "Rutgers Scarlet Knights football",...              []
# N96749   [{"Label": "Queens", "Type": "G", "WikidataId"...              []
# ...                                                    ...             ...
# N819583  [{"Label": "Bright spots on Ceres", "Type": "U...              []
# N139372                                                 []              []
# N430180  [{"Label": "Broadway theatre", "Type": "F", "W...              []
# N522314  [{"Label": "Peugeot RCZ", "Type": "V", "Wikida...              []
# N397875                                                 []              []
#
# [5415 rows x 7 columns]

# %%
# 顯然是原始資料沒有切好
# [Case 1] N773033,N793536,N319440: url跟title_entity都被併到abstract
# [Case 2] N519444,N828921,N714065: abstract被併到title
news_df[news_df['abstract_entity'].isna()]
# Out:
#           category                      subcategory  \
# news_id
# N773033  lifestyle  lifestylefamilyandrelationships
# N519444    finance                    finance-video
# N793536     sports                     football_nfl
# N828921       news                           newsus
# N714065       news                           newsus
# N319440      video                             news
#
#                                                      title  \
# news_id
# N773033           The 50 Most Common Last Names in America
# N519444  The Price You Pay: The spiraling cost of colle...
# N793536  Baker Mayfield injury update: 'No doubt' Brown...
# N828921  The security has been stepped up': Forest Park...
# N714065  [We] walk dogs and pick up poo for free | Why ...
# N319440  Transcripts highlight Sean Hannity's political...
#
#                                                   abstract  \
# news_id
# N773033  What's in a name?\thttps://assets.msn.com/labs...
# N519444      https://assets.msn.com/labs/mind/AAIKUGl.html
# N793536  He'll be in better shape physically and he'll ...
# N828921      https://assets.msn.com/labs/mind/AAJncPt.html
# N714065      https://assets.msn.com/labs/mind/AAJUQ4w.html
# N319440  We're seeing really disturbing things coming o...
#
#                                                        url  \
# news_id
# N773033                                                 []
# N519444                                                 []
# N793536  [{"Label": "Freddie Kitchens", "Type": "P", "W...
# N828921  [{"Label": "Forest Park\u2013DeBaliviere stati...
# N714065  [{"Label": "Animal control service", "Type": "...
# N319440  [{"Label": "Sean Hannity", "Type": "P", "Wikid...
#
#                                               title_entity abstract_entity
# news_id
# N773033                                                NaN             NaN
# N519444                                                 []             NaN
# N793536                                                NaN             NaN
# N828921  [{"Label": "St. Louis", "Type": "G", "Wikidata...             NaN
# N714065  [{"Label": "Animal control service", "Type": "...             NaN
# N319440                                                NaN             NaN

# %%
# 處理 case 1
anomaly_ids = ['N773033','N793536','N319440']
anomaly_cols = ['abstract', 'url', 'title_entity', 'abstract_entity']
anomaly = news_df.loc[anomaly_ids]['abstract'].str.split('\t')
for news_id in anomaly.index:
    anomaly[news_id].append(news_df.loc[news_id, 'url'])
    
# pd.DataFrame(anomaly.tolist(), columns=anomaly_cols, index=anomaly_ids)
news_df.loc[anomaly_ids, anomaly_cols] = pd.DataFrame(anomaly.tolist(), columns=anomaly_cols, index=anomaly_ids)

# %%
# 處理 case 2
anomaly_ids = ['N519444','N828921','N714065']
anomaly_cols = ['title', 'abstract', 'url', 'title_entity', 'abstract_entity']

# abstract後的資料都往後移一格
news_df.loc[anomaly_ids, anomaly_cols[2:]] = news_df.loc[anomaly_ids, anomaly_cols[1:4]].values

anomaly = news_df.loc[anomaly_ids]['title'].str.split('\t')
news_df.loc[anomaly_ids, ['title', 'abstract']] = pd.DataFrame(anomaly.tolist(), columns=['title', 'abstract'], index=anomaly_ids)

# %%
news_df.loc[['N773033','N793536','N319440', 'N519444','N828921','N714065']]
# Out:
#           category                      subcategory  \
# news_id
# N773033  lifestyle  lifestylefamilyandrelationships
# N793536     sports                     football_nfl
# N319440      video                             news
# N519444    finance                    finance-video
# N828921       news                           newsus
# N714065       news                           newsus
#
#                                                      title  \
# news_id
# N773033           The 50 Most Common Last Names in America
# N793536  Baker Mayfield injury update: 'No doubt' Brown...
# N319440  Transcripts highlight Sean Hannity's political...
# N519444   The Price You Pay: The spiraling cost of college
# N828921  The security has been stepped up': Forest Park...
# N714065  [We] walk dogs and pick up poo for free | Why ...
#
#                                                   abstract  \
# news_id
# N773033                                  What's in a name?
# N793536  He'll be in better shape physically and he'll ...
# N319440  We're seeing really disturbing things coming o...
# N519444  In our new series, The Price You Pay," we look...
# N828921  ST. LOUIS (KMOV.com) -- Metro security in one ...
# N714065  A damning audit from July into the St. Louis C...
#
#                                                    url  \
# news_id
# N773033  https://assets.msn.com/labs/mind/AAGO6bg.html
# N793536  https://assets.msn.com/labs/mind/AAIPbTZ.html
# N319440  https://assets.msn.com/labs/mind/BBWymjv.html
# N519444  https://assets.msn.com/labs/mind/AAIKUGl.html
# N828921  https://assets.msn.com/labs/mind/AAJncPt.html
# N714065  https://assets.msn.com/labs/mind/AAJUQ4w.html
#
#                                               title_entity  \
# news_id
# N773033  [{Label": "Surname", "Type": "C", "WikidataId"...
# N793536  [{Label": "Baker Mayfield", "Type": "P", "Wiki...
# N319440  [{Label": "Sean Hannity", "Type": "P", "Wikida...
# N519444                                                 []
# N828921  [{"Label": "Forest Park\u2013DeBaliviere stati...
# N714065  [{"Label": "Animal control service", "Type": "...
#
#                                            abstract_entity
# news_id
# N773033                                                 []
# N793536  [{"Label": "Freddie Kitchens", "Type": "P", "W...
# N319440  [{"Label": "Sean Hannity", "Type": "P", "Wikid...
# N519444                                                 []
# N828921  [{"Label": "St. Louis", "Type": "G", "Wikidata...
# N714065  [{"Label": "Animal control service", "Type": "...

# %%
news_df.to_csv('train/fixed_train_news.tsv', sep='\t')
